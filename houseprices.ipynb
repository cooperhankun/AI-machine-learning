# %% [markdown]
# # 1. Setting goals and basic data collections.
#
# Set a target problem you want to solve. For example, the goal of the analysis is to find the base line factor affecting the value of house holds in California.
#
# There are two main ways to obtain data: (1). loading stored data from local computer (2). the external source data which published on the website or collected through web crawlers.
#
# The most commonly used file format is .csv. A CSV (comma-separated values) file is a simple text file in which information is separated by commas.
#
# Taking the data of California housing prices as an example, we can first download the housing.csv file from the website and save it in the datasets folder.
#
#
#
# # 2. Data loading
#
# Extract data from databases and files and turn them into DataFrame objects. We can open the data through the library:  import pandas as pd -> x=pd.read_csv('C:\\...housing.csv')
#
#
# # 3. Data visualization
#
# Convert datasets structure into chart form ( here we can use matplotlib library).
#
# The common way for example is the histogram for showing the distribution of the variables. Make a correlation matrix and look for the correlations.
#
#
# # 4. Data processing
#
# Data: the data we want or the independent variables, as known as x variables.
#
# Feature name: the column names of the data. (t.ex. housingmedianage, total_rooms, total_bedrooms)
#
# Target: the target variable or the price of the house, as known as dependent variable or y value. (median_house_value)
#
#
# ## Data preparation, conversion and aggregation:
#
# By using the describe data function to check if there are missing values or outliers. Some empty data can be filled or deleted according to some situation. We can choose to drop one or several feature variables if there are some terrible missing.
#
# Clean the data, make the format consistently, some symbols must be removed, convert categorical and text data to numeric data.
#
# Get some statistics from the dataset, for example count and mean.
#
#
#
# # 5. Predictive model creation and evaluation
#
# Initialize the linear regression model.
#
# Define or split the data into training part and test part. For example 67% for training and 33% for test, x_train, x_test, y_train, y_test.
#
# Train the model with training data and predict on the test data.
#
# Do the coefficients analysis.
#
# Check the model performance or accuracy by using MSE(Mean Squared Error)
#
#
# # 6. Some technologies can be used in machine learning process.
#
# Excel: It can simply and intuitively browse data information and find problems.
#
# Numpy and pandas: Used for data import, data descriptions and classifications, etc.
#
# Matplotlib: Visual description.
#
# Sklearn: It used for classification, regression and clustering algorithms.
#
#
#
#
#
#
# # Reference:
#
# https://www.debug8.com/python/t_74583.html
#
# https://www.howtogeek.com/348960/what-is-a-csv-file-and-how-do-i-open-it/
#
# https://en.wikipedia.org/wiki/Scikit-learn
#
# https://www.kaggle.com/paraggurjar/california-house-price-simple-linear-regression
